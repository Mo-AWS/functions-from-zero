# %% [markdown]
# <a href="https://colab.research.google.com/github/Mo-AWS/functions-from-zero/blob/main/Python-lab/Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning statements

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### Variables

# %%
variable = 1
